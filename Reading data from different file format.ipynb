# %%
import pandas as pd

# %%
df1=pd.read_excel(r"C:\Users\user\Downloads\ineuron\pandas\wine_el.xlsx",sheet_name='Sheet1')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2=pd.read_html("https://scikit-learn.org/stable/datasets/toy_dataset.html")

# %%
type(df2)
# Out:
# list

# %%
len(df2)
# Out:
# 4

# %%
df2[0]
# Out:
#                                                  0  \
# 0                     load_boston(*[, return_X_y])
# 1             load_iris(*[, return_X_y, as_frame])
# 2         load_diabetes(*[, return_X_y, as_frame])
# 3  load_digits(*[, n_class, return_X_y, as_frame])
# 4         load_linnerud(*[, return_X_y, as_frame])
# 5             load_wine(*[, return_X_y, as_frame])
# 6    load_breast_cancer(*[, return_X_y, as_frame])
#
#                                                    1
# 0  Load and return the boston house-prices datase...
# 1  Load and return the iris dataset (classificati...
# 2  Load and return the diabetes dataset (regressi...
# 3  Load and return the digits dataset (classifica...
# 4  Load and return the physical excercise linneru...
# 5  Load and return the wine dataset (classificati...
# 6  Load and return the breast cancer wisconsin da...

# %%
for i in range(len(df2)):
    print(df2[i])
# Out:
#                                                  0  \
# 0                     load_boston(*[, return_X_y])
# 1             load_iris(*[, return_X_y, as_frame])
# 2         load_diabetes(*[, return_X_y, as_frame])
# 3  load_digits(*[, n_class, return_X_y, as_frame])
# 4         load_linnerud(*[, return_X_y, as_frame])
# 5             load_wine(*[, return_X_y, as_frame])
# 6    load_breast_cancer(*[, return_X_y, as_frame])
#
#                                                    1
# 0  Load and return the boston house-prices datase...
# 1  Load and return the iris dataset (classificati...
# 2  Load and return the diabetes dataset (regressi...
# 3  Load and return the digits dataset (classifica...
# 4  Load and return the physical excercise linneru...
# 5  Load and return the wine dataset (classificati...
# 6  Load and return the breast cancer wisconsin da...
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# ...

# %%
df2[1]
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  sepal length:         4.3         7.9        5.84        0.83
# 1   sepal width:         2.0         4.4        3.05        0.43
# 2  petal length:         1.0         6.9        3.76        1.76
# 3   petal width:         0.1         2.5        1.20        0.76
#
#        Unnamed: 5
# 0          0.7826
# 1         -0.4194
# 2  0.9490 (high!)
# 3  0.9565 (high!)

# %%
df2[1].to_csv("flower")

# %%
pd.read_csv("flower")
# Out:
#    Unnamed: 0   Unnamed: 0.1  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0           0  sepal length:         4.3         7.9        5.84        0.83
# 1           1   sepal width:         2.0         4.4        3.05        0.43
# 2           2  petal length:         1.0         6.9        3.76        1.76
# 3           3   petal width:         0.1         2.5        1.20        0.76
#
#        Unnamed: 5
# 0          0.7826
# 1         -0.4194
# 2  0.9490 (high!)
# 3  0.9565 (high!)

# %%
# cloud storage# collection# dictionary# json

# %%
s="""{"name":"AAA","age":32,"no_of_kids":3,"name_of_kids":["ee","et","isa"]}"""

# %%
import json

# %%
s1=json.loads(s)

# %%
type(s1)
# Out:
# dict

# %%
pd.DataFrame(s1)
# Out:
#   name  age  no_of_kids name_of_kids
# 0  AAA   32           3           ee
# 1  AAA   32           3           et
# 2  AAA   32           3          isa

# %%
pd.DataFrame(s1,columns=["name_of_kids"])
# Out:
#   name_of_kids
# 0           ee
# 1           et
# 2          isa

# %%
import requests

# %%
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js=res.json()

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42831',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42831/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42831/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42831/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/42831',
#  'id': 957213866,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0NzAwNjg1ODg0',
#  'number': 42831,
#  'title': 'TST: raising ValueError when inserting one dataframe in another',
#  'user': {'login': 'debnathshoham',
#   'id': 6472290,
#   'node_id': 'MDQ6VXNlcjY0NzIyOTA=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6472290?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/debnathshoham',
#   'html_url': 'https://github.com/debnathshoham',
# ...

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# TST: raising ValueError when inserting one dataframe in another
# REF: remove unnecessary return value from ensure_data
# BUG: Exactly same check multiple times in if statement
# BUG: column names with degree sign make query fail
# DOC: .loc doesn't document that it can take sets or dicts as arguments
# PERF: column_arrays
# BUG: Pass copy argument to expanddim constructor in concat.
# ENH: change default min_count value for pandas.core.resample.Resampler.sum()
# BUG: Fix dtypes for read_json
# BUG: erroneous initialization of a DataFrame with Series objects
# BUG: nlargest raises TypeError "No matching signature found" on Float64Dtype Series, versions >1.3.0
# rollback and rollforward both of them  gives  same response for month end business day
# BUG: DataFrame constructor fails to repeat length-1 list to length of index if it contains a Timestamp/datetime64
# DOC: Fixed GL02 errors in documentation
# BUG: read_csv converts NaN to 1.0 in certain circumstances
# ...

# %%
df4=pd.DataFrame(js,columns=['url','title'])

# %%
df4.to_csv('json_dump.csv')

# %%
lis=[]

# %%
for i in range(len(js)):
    lis.append(js[i]['user'])

# %%
pd.DataFrame(lis)
# Out:
#                 login        id               node_id  \
# 0   minientertainment  27546987  MDQ6VXNlcjI3NTQ2OTg3
# 1            lilisako  33516104  MDQ6VXNlcjMzNTE2MTA0
# 2         saehuihwang  57047354  MDQ6VXNlcjU3MDQ3MzU0
# 3            zeitlinv  56974083  MDQ6VXNlcjU2OTc0MDgz
# 4              isVoid  13521008  MDQ6VXNlcjEzNTIxMDA4
# 5     PeterTrefonasIv  87782187  MDQ6VXNlcjg3NzgyMTg3
# 6        raphaelquast  22773387  MDQ6VXNlcjIyNzczMzg3
# 7       debnathshoham   6472290  MDQ6VXNlcjY0NzIyOTA=
# 8        jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 9           lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 10       jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 11      debnathshoham   6472290  MDQ6VXNlcjY0NzIyOTA=
# 12         multimeric   5019367  MDQ6VXNlcjUwMTkzNjc=
# 13      debnathshoham   6472290  MDQ6VXNlcjY0NzIyOTA=
# 14         neelmraman  42706631  MDQ6VXNlcjQyNzA2NjMx
# 15     stevebachmeier  23350991  MDQ6VXNlcjIzMzUwOTkx
# ...

# %%
df11=pd.read_csv(r"C:\Users\user\Downloads\ineuron\pandas\wine.csv")

# %%
df1.to_pickle("my_pickle")

# %%
h5_data=pd.HDFStore("test.h5")

# %%
h5_data['obj1']=df1
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block2_values] [items->Index(['country', 'description', 'designation', 'province', 'region_1',
#        'region_2', 'variety', 'winery'],
#       dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1
# Out:
#        Unnamed: 0 country                                        description  \
# 0               0      US  This tremendous 100% varietal wine hails from ...
# 1               1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2               2      US  Mac Watson honors the memory of a wine once ma...
# 3               3      US  This spent 20 months in 30% new French oak, an...
# 4               4  France  This is the top wine from La BÃ©gude, named af...
# ...           ...     ...                                                ...
# 16378       16378  France  Rounded and full, this has lime and red berry ...
# 16379       16379   Spain  The leathery red-berry aromas are a tad stretc...
# 16380       16380      US  BFM stands for Blow Your Freakin' Mind, say th...
# 16381       16381      US  Chardonnay is the sweet spot in the white wine...
# 16382       16382      US  Shows the robust mouthfeel and high alcohol th...
#
# ...

# %%
form1=pd.read_csv(r"C:\Users\user\Downloads\ineuron\pandas\wine.csv")

# %%
form1.to_pickle("wine-pickle")

# %%
file1=pd.HDFStore("form2.h5")

# %%
file1['obj1']=form1
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['country', 'description', 'designation', 'province', 'region_1',
#        'region_2', 'variety', 'winery'],
#       dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
file1.put('obj2',form1,format='table')

# %%
file1.select('obj2',where=[ 'index >=10 and index <=15 '])
# Out:
#     Unnamed: 0 country                                        description  \
# 10          10   Italy  Elegance, complexity and structure come togeth...
# 11          11      US  From 18-year-old vines, this supple well-balan...
# 12          12      US  A standout even in this terrific lineup of 201...
# 13          13  France  This wine is in peak condition. The tannins an...
# 14          14      US  With its sophisticated mix of mineral, acid an...
# 15          15      US  First made in 2006, this succulent luscious Ch...
#
#                         designation  points  price            province  \
# 10               Ronco della Chiesa      95   80.0  Northeastern Italy
# 11  Estate Vineyard Wadensvil Block      95   48.0              Oregon
# 12                   Weber Vineyard      95   48.0              Oregon
# 13          Château Montus Prestige      95   90.0    Southwest France
# 14                   Grace Vineyard      95  185.0              Oregon
# ...
